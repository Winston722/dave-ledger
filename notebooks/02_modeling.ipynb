# %%
# Cell 1: Magic Commands
# %load_ext autoreload
# %autoreload 2

import sys
import pandas as pd
from pathlib import Path

# Optional: If you haven't run 'pip install -e .' yet, you might need this hack.
# But if you did the install, you don't need these two lines:
# project_root = Path('..').resolve() 
# sys.path.append(str(project_root / 'src'))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Cell 2: Imports
from dave_ledger import pipeline
from dave_ledger.etl import transform 
from dave_ledger.analysis import valuation

# Check that it's working
print("Pipeline loaded from:", pipeline.__file__)
# Out:
# Pipeline loaded from: /home/winstonunderwood/projects/dave-ledger/src/dave_ledger/pipeline.py

# %%
# Cell 3: Run the Master Pipeline
# This calls run_dave() which orchestrates the whole flow
board = pipeline.run_dave()

# Inspect the results
display(board.sort_values('vorp', ascending=False).head(10))
# Out:
# 2026-01-02 16:29:55,695 - INFO - ✅ Configuration Loaded.
# 2026-01-02 16:29:55,696 - INFO - 1. [TRANSFORM] Loading & Merging History...
# 2026-01-02 16:29:55,807 - INFO - 🔧 Renaming 'pfr_player_id' to 'player_id' in snaps
# 2026-01-02 16:29:55,815 - INFO - 🔧 Renaming 'gsis_id' to 'player_id' in rosters
# 2026-01-02 16:29:55,980 - INFO -    -> Loaded 89515 rows of history.
# 2026-01-02 16:29:55,981 - INFO - 2. [SCORING] Applying League Rules...
# 2026-01-02 16:29:56,018 - INFO - 3. [BASELINES] Calculating League Replacement Levels...
# 2026-01-02 16:29:56,031 - INFO - 📉 QB Baseline: 2.0 starts -> Rank 48 (Dillon Gabriel) = 8.61 PPG
# 2026-01-02 16:29:56,033 - INFO - 📉 RB Baseline: 2.5 starts -> Rank 75 (Zavier Scott) = 4.24 PPG
# 2026-01-02 16:29:56,034 - INFO - 📉 WR Baseline: 3.5 starts -> Rank 92 (Pat Bryant) = 5.97 PPG
# 2026-01-02 16:29:56,035 - INFO - 📉 TE Baseline: 1.0 starts -> Rank 18 (Colston Loveland) = 9.42 PPG
# ...
