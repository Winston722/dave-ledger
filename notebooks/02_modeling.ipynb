# %%
# Cell 1: Magic Commands
# %load_ext autoreload
# %autoreload 2

import sys
import pandas as pd
from pathlib import Path

# Optional: If you haven't run 'pip install -e .' yet, you might need this hack.
# But if you did the install, you don't need these two lines:
# project_root = Path('..').resolve() 
# sys.path.append(str(project_root / 'src'))

# %%
# Cell 2: Imports
from dave_ledger import pipeline
from dave_ledger.etl import transform 
from dave_ledger.analysis import valuation

# Check that it's working
print("Pipeline loaded from:", pipeline.__file__)
# Out:
# Pipeline loaded from: /home/winstonunderwood/projects/dave-ledger/src/dave_ledger/pipeline.py

# %%
# Cell 3: Run the Master Pipeline
# This calls run_dave() which orchestrates the whole flow
board = pipeline.run_dave()

# Inspect the results
display(board.sort_values('vorp', ascending=False).head(10))
# Out:
# 2026-01-02 15:47:17,290 - INFO - ✅ Configuration Loaded.
# 2026-01-02 15:47:17,291 - INFO - 1. [TRANSFORM] Loading & Merging History...
# 2026-01-02 15:47:17,426 - INFO - 🔧 Renaming 'pfr_player_id' to 'player_id' in snaps
# 2026-01-02 15:47:17,436 - INFO - 🔧 Renaming 'gsis_id' to 'player_id' in rosters
# 2026-01-02 15:47:17,632 - INFO -    -> Loaded 89515 rows of history.
# 2026-01-02 15:47:17,633 - INFO - 2. [SCORING] Applying League Rules...
# 2026-01-02 15:47:17,673 - INFO - 3. [BASELINES] Calculating League Replacement Levels...
# 2026-01-02 15:47:17,691 - INFO - 📉 QB Baseline: 2.0 starts -> Rank 48 (Dillon Gabriel) = 7.01 PPG
# 2026-01-02 15:47:17,693 - INFO - 📉 RB Baseline: 2.5 starts -> Rank 75 (Braelon Allen) = 3.33 PPG
# 2026-01-02 15:47:17,694 - INFO - 📉 WR Baseline: 3.5 starts -> Rank 92 (Isaiah Hodgins) = 3.50 PPG
# 2026-01-02 15:47:17,695 - INFO - 📉 TE Baseline: 1.0 starts -> Rank 18 (AJ Barner) = 5.87 PPG
# 2026-01-02 15:47:17,696 - INFO - 📉 K Baseline: 1.0 starts -> Rank 12 (Zane Gonzalez) = 0.00 PPG
# 2026-01-02 15:47:17,697 - WARNING - ⚠️ DL: Not enough players to fill 28 spots.
# 2026-01-02 15:47:17,698 - INFO - 📉 LB Baseline: 2.0 starts -> Rank 36 (Boye Mafe) = 0.00 PPG
# 2026-01-02 15:47:17,699 - WARNING - ⚠️ DB: Not enough players to fill 26 spots.
# 2026-01-02 15:47:17,700 - INFO - 4. [VALUATION] Forecasting Asset Prices...
# 2026-01-02 15:47:17,715 - INFO -    -> Running Bayesian Availability Engine...
# 2026-01-02 15:47:19,986 - INFO -    -> Calculating Weighted Talent Baseline...
# 2026-01-02 15:47:28,695 - INFO -    -> Calculating Risk Metrics...
# 2026-01-02 15:47:28,700 - INFO -    -> Running Infinite Horizon Projection...
# 2026-01-02 15:47:28,745 - INFO - ✅ Pipeline Complete.
#        player_id player_name player_display_name fantasy_group position_group  \
# 906   00-0039851      D.Maye          Drake Maye            QB             QB
# 2143  00-0040691      J.Dart         Jaxson Dart            QB             QB
# 236   00-0034857     J.Allen          Josh Allen            QB             QB
# 862   00-0039732       B.Nix              Bo Nix            QB             QB
# 937   00-0039918  C.Williams      Caleb Williams            QB             QB
# 413   00-0036389     J.Hurts         Jalen Hurts            QB             QB
# 932   00-0039910   J.Daniels      Jayden Daniels            QB             QB
# 403   00-0036355   J.Herbert      Justin Herbert            QB             QB
# 217   00-0034796   L.Jackson       Lamar Jackson            QB             QB
# 796   00-0039163    C.Stroud         C.J. Stroud            QB             QB
#
#                                            headshot_url  season  week  \
# 906   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 2143  https://static.www.nfl.com/image/upload/f_auto...    2025     2
# 236   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 862   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 937   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 413   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 932   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 403   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 217   https://static.www.nfl.com/image/upload/f_auto...    2025     1
# 796   https://static.www.nfl.com/image/upload/f_auto...    2025     1
#
#      season_type team  ... current_team  birth_year  current_age  points  \
# 906          REG   NE  ...           NE        2002           24   18.78
# 2143         REG  NYG  ...          NYG        2003           23   -0.30
# 236          REG  BUF  ...          BUF        1996           30   42.76
# 862          REG  DEN  ...          DEN        2000           26   12.84
# 937          REG  CHI  ...          CHI        2001           25   26.20
# 413          REG  PHI  ...          PHI        1998           28   24.28
# 932          REG  WAS  ...          WAS        2000           26   22.12
# 403          REG  LAC  ...          LAC        1998           28   33.92
# 217          REG  BAL  ...          BAL        1997           29   33.36
# 796          REG  HOU  ...          HOU        2001           25    9.72
#
#       availability_score  talent_ppg   risk_cv    dcf_value  \
# 906             0.866667   18.541565  0.392834  1656.370340
# 2143            0.859459   17.013846  0.623624  1597.022177
# 236             0.960000   23.471454  0.376015  1565.008139
# 862             0.959259   18.491626  0.423007  1564.012807
# 937             0.959259   16.944466  0.481415  1560.777625
# 413             0.921905   20.973989  0.359790  1548.420807
# 932             0.792593   19.427832  0.438532  1357.699210
# 403             0.940952   17.927810  0.421244  1350.880031
# 217             0.836190   20.753374  0.461332  1303.657741
# 796             0.898592   15.049196  0.474384  1298.532347
#
#       replacement_value         vorp
# 906          272.014308  1384.356032
# 2143         272.014308  1325.007870
# 236          272.014308  1292.993831
# 862          272.014308  1291.998499
# 937          272.014308  1288.763317
# 413          272.014308  1276.406500
# 932          272.014308  1085.684902
# 403          272.014308  1078.865724
# 217          272.014308  1031.643434
# 796          272.014308  1026.518039
#
# [10 rows x 129 columns]
