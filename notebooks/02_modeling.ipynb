# %%
# Cell 1: Magic Commands
# %load_ext autoreload
# %autoreload 2

import sys
import pandas as pd
from pathlib import Path

# Optional: If you haven't run 'pip install -e .' yet, you might need this hack.
# But if you did the install, you don't need these two lines:
# project_root = Path('..').resolve() 
# sys.path.append(str(project_root / 'src'))

# %%
# Cell 2: Imports
from dave_ledger import pipeline
from dave_ledger.etl import transform 
from dave_ledger.analysis import valuation

# Check that it's working
print("Pipeline loaded from:", pipeline.__file__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Cell 2: Imports
#       2 from dave_ledger import pipeline
# ----> 3 from dave_ledger.etl import transform
#       4 from dave_ledger.analysis import valuation
#       6 # Check that it's working
#
# ImportError: cannot import name 'transform' from 'dave_ledger.etl' (/home/winstonunderwood/projects/dave-ledger/src/dave_ledger/etl/__init__.py)
